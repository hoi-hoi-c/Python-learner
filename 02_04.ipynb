# %%
a='Python World'
print(a[0])
print(a[11])
print(a[-1])
print(a[-12])

a='Hello world'
print(a[0:11])
print(a[:5])
print(a[3:])
print(a[:])
# Out:
# P
# d
# d
# P
# Hello world
# Hello
# lo world
# Hello world

# %%
a='Python world'
a=a.upper()
print(a)

a='Python world'
a=a.replace('o','a')
print(a)

a='What a wonderful Python world'
aList=a.split('w')
print(aList)
print(a)
# Out:
# PYTHON WORLD
# Pythan warld
# ['What a ', 'onderful Python ', 'orld']
# What a wonderful Python world

# %%
ss='Python is Easy. 그래서 programming이 재미있습니다.^^'
ss=ss.upper()
print(ss)
ss=ss.lower()
print(ss)
ss='Python is Easy. 그래서 programming이 재미있습니다.^^'
ss=ss.swapcase()
print(ss)
ss=ss.title()
print(ss)
# Out:
# PYTHON IS EASY. 그래서 PROGRAMMING이 재미있습니다.^^
# python is easy. 그래서 programming이 재미있습니다.^^
# pYTHON IS eASY. 그래서 PROGRAMMING이 재미있습니다.^^
# Python Is Easy. 그래서 Programming이 재미있습니다.^^

# %%
aa=[10,20,30,40]
print('aa[-1]은 %d, aa[-2]는 %d'%(aa[-1],aa[-2]))

print(aa[0:3])
print(aa[2:4])

print(aa[2:])
print(aa[:2])
# Out:
# aa[-1]은 40, aa[-2]는 30
# [10, 20, 30]
# [30, 40]
# [30, 40]
# [10, 20]

# %%
aa=[10,20,30]
bb=[40,50,60]
print(aa+bb)
print(aa*3)
# Out:
# [10, 20, 30, 40, 50, 60]
# [10, 20, 30, 10, 20, 30, 10, 20, 30]

# %%
aa=[10,20,30,40,50,60,70]
print(aa[::2])
print(aa[::-2])
print(aa[::3])
print(aa[::-3])
print(aa[::-4])
print(aa[::-1])
print(aa[::1])
# Out:
# [10, 30, 50, 70]
# [70, 50, 30, 10]
# [10, 40, 70]
# [70, 40, 10]
# [70, 30]
# [70, 60, 50, 40, 30, 20, 10]
# [10, 20, 30, 40, 50, 60, 70]

# %%
aa=[10,20,30]
aa[1]=200
print(aa)
# Out:
# [10, 200, 30]

# %%
aa=[10,20,30]
aa[1:2]=[200,201]
print(aa)

aa=[10,20,30]
aa[1:2]=200,201
print(aa)
# Out:
# [10, 200, 201, 30]
# [10, 200, 201, 30]

# %%
aa=[10,20,30,40,50,60,70]
aa[0:2]=[100,200,300,400]
print(aa)
# Out:
# [100, 200, 300, 400, 30, 40, 50, 60, 70]

# %%
aa=[10,20,30]
aa[1]=[200,201]
print(aa)

aa=[10,20,30]
aa[1]=200,201
print(aa)
# Out:
# [10, [200, 201], 30]
# [10, (200, 201), 30]

# %%
aa=[10,20,30]
del(aa[1])
print(aa)
# Out:
# [10, 30]

# %%
aa=[10,20,30,40,50]
aa[1:4]=[]
print(aa)
# Out:
# [10, 50]

# %%
aa=[10,20,30]; aa=[]; print(aa)
aa=[10,20,30]; aa=None; print(aa)
aa=[10,20,30]; del(aa[:])
print(aa)
# Out:
# []
# None
# []
