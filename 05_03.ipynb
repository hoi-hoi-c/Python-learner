# %%
#read(): 전체 텍스트를 읽는다
infile=open(r"C:\Users\Admini\Desktop\p\phones.txt","r",encoding='utf-8')
lines=infile.read()
print(lines)
# Out:
# 홍길동 010-1234
# 김철수 010-1235
# 김영희 010-1236
# 장경준 010-1237

# %%
#read(): 전체 텍스트를 읽는다
infile=open(r"C:\Users\Admini\Desktop\p\phones.txt","r",encoding='utf-8')
lines=infile.readlines()
print(lines)
# Out:
# ['홍길동 010-1234\n', '김철수 010-1235\n', '김영희 010-1236\n', '장경준 010-1237']

# %%
#read(): 전체 텍스트를 읽는다
infile=open(r"C:\Users\Admini\Desktop\p\phones.txt","r",encoding='utf-8')
for line in infile:
    line=line.rstrip()
    print(line)
infile.close()
# Out:
# 홍길동 010-1234
# 김철수 010-1235
# 김영희 010-1236
# 장경준 010-1237

# %%
outfile=open(r"C:\Users\Admini\Desktop\p\phones1.txt","w",encoding='utf-8')
outfile.write('최정훈 010-9999\n')
outfile.write('김도형 010-9998\n')
outfile.write('장경준 010-9997\n')
outfile.close()

# %%
outfile=open(r"C:\Users\Admini\Desktop\p\phones.txt","a",encoding='utf-8')
outfile.write('강감찬 010-1111\n')
outfile.write('김유신 010-1112\n')
outfile.write('정약용 010-1113\n')
outfile.close()

# %%
with open(r"C:\Users\Admini\Desktop\p\phones.txt","r",encoding='utf-8') as inFp:
    inList=inFp.readlines()
    print(inList)
# Out:
# ['홍길동 010-1234\n', '김철수 010-1235\n', '김영희 010-1236\n', '장경준 010-1237\n', '강감찬 010-1111\n', '김유신 010-1112\n', '정약용 010-1113\n']

# %%
outFp=None
outStr=""

outFp=open(r"C:\Users\Admini\Desktop\p\data2.txt","w",encoding='utf-8')

while True:
    outStr=input('내용 입력: ')
    if outStr !="":
        outFp.writelines(outStr+"\n")
    else:
        break

outFp.close()
print("----정상적으로 파일에 씀----")
# Out:
# 내용 입력: 파이썬
# 내용 입력: 수업중
# 내용 입력: 입니다.
# 내용 입력:
# ----정상적으로 파일에 씀----

# %%
infile=open(r"C:\Users\Admini\Desktop\p\proverbs.txt","r",encoding='utf-8')
for line in infile:
    line=line.rstrip()
    word_list=line.split()
    for word in word_list:
        print(word);

infile.close()
# Out:
# All's
# well
# that
# ends
# well.
# Bad
# news
# travels
# fast.
# Well
# begun
# is
# half
# done.
# Birds
# of
# a
# feather
# flock
# together.

# %%
inFp=None
inStr=""

inFp=open(r"C:\Users\Admini\Desktop\p\data2.txt","r",encoding='utf-8')

inStr=inFp.readline()
print(inStr,end="")

inStr=inFp.readline()
print(inStr,end="")

inStr=inFp.readline()
print(inStr,end="")

inFp.close()
# Out:
# 파이썬
# 수업중
# 입니다.

# %%
inFp=None
inStr=""

inFp=open(r"C:\Users\Admini\Desktop\p\data2.txt","r",encoding='utf-8')

while True:
    inStr=inFp.readline()
    if inStr=="":
        break;
    print(inStr,end="")
    
inFp.close()
# Out:
# 파이썬
# 수업중
# 입니다.

# %%
inFp=None
inStr=""

inFp=open(r"C:\Users\Admini\Desktop\p\data2.txt","r",encoding='utf-8')

inList=inFp.readlines()
print(inList)

inFp.close()
# Out:
# ['파이썬\n', '수업중\n', '입니다.\n']
